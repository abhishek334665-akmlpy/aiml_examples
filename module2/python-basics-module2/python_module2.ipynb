# %%
import csv

with open("customers.csv", "r") as file:
    reader = csv.reader(file)

    header = next(reader)

    print(header)

    for row in reader:
        print(row)

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

plt.plot(x, y)
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

plt.plot(x, y)
